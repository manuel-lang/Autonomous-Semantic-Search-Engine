# %%
import json
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 import Features, KeywordsOptions, EntitiesOptions

# %%
import textract
text = textract.process("../backend/nextiterationhackathon2018/pdf/Waechter2018.pdf").decode("utf-8")

# %%
natural_language_understanding = NaturalLanguageUnderstandingV1(
  username='cccb5076-87bd-4992-b99e-29a0f258460b',
  password='Prop61GOuNtl',
  version='2018-03-16')

# %%
response = natural_language_understanding.analyze(
  text=text,
    features=Features(
        entities=EntitiesOptions(
          sentiment=False,
          limit=30),
        keywords=KeywordsOptions(
          sentiment=False,
          emotion=False,
          limit=20)))

# %%
print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 5,
#     "text_characters": 50000,
#     "features": 2
#   },
#   "language": "en",
#   "keywords": [
#     {
#       "text": "robot",
#       "relevance": 0.967098
#     },
#     {
#       "text": "object",
#       "relevance": 0.779927
#     },
#     {
#       "text": "replacement manager",
#       "relevance": 0.762717
#     },
#     {
#       "text": "memory",
#       "relevance": 0.600086
#     },
#     {
#       "text": "domain description",
#       "relevance": 0.574182
#     },
#     {
#       "text": "plan execution",
#       "relevance": 0.568509
#     },
#     {
#       "text": "current world state",
#       "relevance": 0.550633
#     },
#     {
#       "text": "natural language",
#       "relevance": 0.53752
#     },
#     {
#       "text": "goal",
#       "relevance": 0.508297
#     },
#     {
#       "text": "robot development environment",
#       "relevance": 0.49706
#     },
#     {
#       "text": "object replacement",
#       "relevance": 0.465312
#     },
#     {
#       "text": "location",
#       "relevance": 0.458747
#     },
#     {
#       "text": "example",
#       "relevance": 0.457946
#     },
#     {
#       "text": "action",
#       "relevance": 0.45131
#     },
#     {
#       "text": "NLU component",
#       "relevance": 0.440097
#     },
#     {
#       "text": "nl understanding component",
#       "relevance": 0.434902
#     },
#     {
#       "text": "structural bootstrapping",
#       "relevance": 0.434777
#     },
#     {
#       "text": "symbolic representations",
#       "relevance": 0.422949
#     },
#     {
#       "text": "objects",
#       "relevance": 0.415746
#     },
#     {
#       "text": "human feedback",
#       "relevance": 0.411462
#     }
#   ],
#   "entities": [
#     {
#       "type": "JobTitle",
#       "text": "Replacement Manager",
#       "relevance": 0.757949,
#       "count": 17
#     },
#     {
#       "type": "Organization",
#       "text": "Plan Execution & Monitoring",
#       "relevance": 0.368946,
#       "count": 3
#     },
#     {
#       "type": "Company",
#       "text": "ArmarX",
#       "relevance": 0.360703,
#       "count": 5
#     },
#     {
#       "type": "Organization",
#       "text": "NLU",
#       "relevance": 0.359726,
#       "count": 3
#     },
#     {
#       "type": "Organization",
#       "text": "NL",
#       "relevance": 0.347963,
#       "count": 3
#     },
#     {
#       "type": "Company",
#       "text": "NLU",
#       "relevance": 0.345981,
#       "count": 4
#     },
#     {
#       "type": "Company",
#       "text": "axiom",
#       "relevance": 0.338486,
#       "count": 8
#     },
#     {
#       "type": "Company",
#       "text": "MemoryX",
#       "relevance": 0.284771,
#       "count": 2
#     },
#     {
#       "type": "Location",
#       "text": "Karlsruhe",
#       "relevance": 0.278459,
#       "disambiguation": {
#         "subtype": [
#           "GermanUrbanDistrict",
#           "City"
#         ],
#         "name": "Karlsruhe",
#         "dbpedia_resource": "http://dbpedia.org/resource/Karlsruhe"
#       },
#       "count": 2
#     },
#     {
#       "type": "Organization",
#       "text": "Aalto University",
#       "relevance": 0.268149,
#       "disambiguation": {
#         "subtype": [
#           "Location",
#           "CollegeUniversity"
#         ],
#         "name": "Aalto University",
#         "dbpedia_resource": "http://dbpedia.org/resource/Aalto_University"
#       },
#       "count": 1
#     },
#     {
#       "type": "Location",
#       "text": "Innsbruck",
#       "relevance": 0.262514,
#       "disambiguation": {
#         "subtype": [
#           "City"
#         ],
#         "name": "Innsbruck",
#         "dbpedia_resource": "http://dbpedia.org/resource/Innsbruck"
#       },
#       "count": 1
#     },
#     {
#       "type": "Location",
#       "text": "Denmark",
#       "relevance": 0.261154,
#       "disambiguation": {
#         "subtype": [
#           "Brand",
#           "AdministrativeDivision",
#           "GovernmentalJurisdiction",
#           "Kingdom",
#           "Country"
#         ],
#         "name": "Denmark",
#         "dbpedia_resource": "http://dbpedia.org/resource/Denmark"
#       },
#       "count": 1
#     },
#     {
#       "type": "Location",
#       "text": "Austria",
#       "relevance": 0.260747,
#       "disambiguation": {
#         "subtype": [
#           "AdministrativeDivision",
#           "GovernmentalJurisdiction",
#           "Country"
#         ],
#         "name": "Austria",
#         "dbpedia_resource": "http://dbpedia.org/resource/Austria"
#       },
#       "count": 1
#     },
#     {
#       "type": "PrintMedia",
#       "text": "Robotics and Autonomous Systems",
#       "relevance": 0.259944,
#       "count": 1
#     },
#     {
#       "type": "Person",
#       "text": "Justus Piaterb",
#       "relevance": 0.257163,
#       "count": 1
#     },
#     {
#       "type": "Location",
#       "text": "Germany",
#       "relevance": 0.256586,
#       "disambiguation": {
#         "subtype": [
#           "GovernmentalJurisdiction",
#           "Country"
#         ],
#         "name": "Germany",
#         "dbpedia_resource": "http://dbpedia.org/resource/Germany"
#       },
#       "count": 1
#     },
#     {
#       "type": "Location",
#       "text": "Finland",
#       "relevance": 0.25655,
#       "disambiguation": {
#         "subtype": [
#           "AdministrativeDivision",
#           "GovernmentalJurisdiction",
#           "Profession",
#           "Country"
#         ],
#         "name": "Finland",
#         "dbpedia_resource": "http://dbpedia.org/resource/Finland"
#       },
#       "count": 1
#     },
#     {
#       "type": "Person",
#       "text": "Kaisera",
#       "relevance": 0.256208,
#       "disambiguation": {
#         "subtype": [
#           "Politician",
#           "NoblePerson"
#         ],
#         "name": "Kapaakea",
#         "dbpedia_resource": "http://dbpedia.org/resource/Kapaakea"
#       },
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "b University of Innsbruck",
#       "relevance": 0.254388,
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "c University of Southern Denmark",
#       "relevance": 0.252361,
#       "count": 1
#     },
#     {
#       "type": "Location",
#       "text": "Tamim Asfoura",
#       "relevance": 0.247589,
#       "disambiguation": {
#         "subtype": [
#           "City"
#         ]
#       },
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "Institute of Technology",
#       "relevance": 0.247026,
#       "count": 1
#     },
#     {
#       "type": "Company",
#       "text": "Google",
#       "relevance": 0.243114,
#       "disambiguation": {
#         "subtype": [
#           "AcademicInstitution",
#           "AwardPresentingOrganization",
#           "OperatingSystemDeveloper",
#           "ProgrammingLanguageDeveloper",
#           "SoftwareDeveloper",
#           "VentureFundedCompany"
#         ],
#         "name": "Google",
#         "dbpedia_resource": "http://dbpedia.org/resource/Google"
#       },
#       "count": 1
#     },
#     {
#       "type": "Person",
#       "text": "Campusvej",
#       "relevance": 0.241837,
#       "count": 1
#     }
#   ],
#   "warnings": [
#     "Text content exceeds 50000 character limit. Only first 50000 characters processed..."
#   ]
# }
